# %% [markdown]
# # Download dataset

# %%
# Download dataset from Kaggle using kagglehub library
import kagglehub

path = kagglehub.dataset_download("likithagedipudi/war-economic-and-livelihood-impact-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.10M/6.10M [00:00<00:00, 6.69MB/s]
# Extracting files...
# Path to dataset files: /home/thomas/.cache/kagglehub/datasets/likithagedipudi/war-economic-and-livelihood-impact-dataset/versions/1

# %% [markdown]
# # Initial dataset investigation

# %%
# Load the dataset using pandas
import pandas as pd

df = pd.read_csv(path + "/war_economic_impact_dataset.csv")

# %%
df.head()
# Out:
#       Conflict_Name                  Conflict_Type       Region  Start_Year  \
# 0      WWII (Japan)                      World War    East Asia        1939
# 1  Israel-Hamas War                 Asymmetric War  Middle East        2023
# 2  Syrian Civil War                      Civil War  Middle East        2011
# 3    WWII (Germany)                      World War       Europe        1939
# 4   Afghanistan War  Interstate/Counter-insurgency   South Asia        2001
#
#    End_Year    Status   Primary_Country  Pre_War_Unemployment_%  \
# 0      1945  Resolved             Japan                    7.49
# 1      2026   Ongoing  Palestine (Gaza)                    8.18
# 2      2026   Ongoing             Syria                   12.70
# 3      1945  Resolved           Germany                   14.06
# 4      2021  Resolved       Afghanistan                    5.38
#
#    During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Conflict_Name', 'Conflict_Type', 'Region', 'Start_Year', 'End_Year',
#        'Status', 'Primary_Country', 'Pre_War_Unemployment_%',
#        'During_War_Unemployment_%', 'Unemployment_Spike_Percentage_Points',
#        'Most_Affected_Sector', 'Youth_Unemployment_Change_%',
#        'Pre_War_Poverty_Rate_%', 'During_War_Poverty_Rate_%',
#        'Extreme_Poverty_Rate_%', 'Food_Insecurity_Rate_%',
#        'Households_Fallen_Into_Poverty_Estimate', 'GDP_Change_%',
#        'Inflation_Rate_%', 'Currency_Devaluation_%', 'Cost_of_War_USD',
#        'Estimated_Reconstruction_Cost_USD', 'Informal_Economy_Size_Pre_War_%',
#        'Informal_Economy_Size_During_War_%', 'Black_Market_Activity_Level',
#        'Primary_Black_Market_Goods', 'Currency_Black_Market_Rate_Gap_%',
#        'War_Profiteering_Documented'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Conflict_Name                            100000 non-null  str
#  1   Conflict_Type                            100000 non-null  str
#  2   Region                                   100000 non-null  str
#  3   Start_Year                               100000 non-null  int64
#  4   End_Year                                 100000 non-null  int64
#  5   Status                                   100000 non-null  str
#  6   Primary_Country                          100000 non-null  str
#  7   Pre_War_Unemployment_%                   100000 non-null  float64
#  8   During_War_Unemployment_%                100000 non-null  float64
#  9   Unemployment_Spike_Percentage_Points     100000 non-null  float64
# ...

# %%
df.shape
# Out:
# (100000, 28)

# %%
df.describe()
# Out:
#           Start_Year       End_Year  Pre_War_Unemployment_%  \
# count  100000.000000  100000.000000           100000.000000
# mean     1999.401340    2009.039940                9.017027
# std        29.957153      30.552183                3.458406
# min      1939.000000    1945.000000                3.000000
# 25%      1996.000000    2011.000000                6.030000
# 50%      2011.000000    2026.000000                9.020000
# 75%      2022.000000    2026.000000               12.000000
# max      2025.000000    2026.000000               15.000000
#
#        During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  \
# count              100000.000000                         100000.000000
# mean                   22.625199                             13.608181
# std                    13.818295                             11.960175
# min                     3.360000                              0.320000
# ...

# %% [markdown]
# ## Quality check

# %%
duplicated_rows = df[df.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [Conflict_Name, Conflict_Type, Region, Start_Year, End_Year, Status, Primary_Country, Pre_War_Unemployment_%, During_War_Unemployment_%, Unemployment_Spike_Percentage_Points, Most_Affected_Sector, Youth_Unemployment_Change_%, Pre_War_Poverty_Rate_%, During_War_Poverty_Rate_%, Extreme_Poverty_Rate_%, Food_Insecurity_Rate_%, Households_Fallen_Into_Poverty_Estimate, GDP_Change_%, Inflation_Rate_%, Currency_Devaluation_%, Cost_of_War_USD, Estimated_Reconstruction_Cost_USD, Informal_Economy_Size_Pre_War_%, Informal_Economy_Size_During_War_%, Black_Market_Activity_Level, Primary_Black_Market_Goods, Currency_Black_Market_Rate_Gap_%, War_Profiteering_Documented]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.nunique()
# Out:
# Conflict_Name                                  11
# Conflict_Type                                   5
# Region                                          5
# Start_Year                                     10
# End_Year                                        5
# Status                                          2
# Primary_Country                                13
# Pre_War_Unemployment_%                       1201
# During_War_Unemployment_%                    7188
# Unemployment_Spike_Percentage_Points         6226
# Most_Affected_Sector                            6
# Youth_Unemployment_Change_%                  7786
# Pre_War_Poverty_Rate_%                       2501
# During_War_Poverty_Rate_%                    7116
# Extreme_Poverty_Rate_%                       4432
# Food_Insecurity_Rate_%                       5568
# Households_Fallen_Into_Poverty_Estimate     62109
# GDP_Change_%                                 6933
# Inflation_Rate_%                            15512
# ...

# %% [markdown]
# ISSUES: Only 11 distinct conflicts. 10000 synthetic but good data. Hence not enough conflict and too synthetic.

# %% [markdown]
# ### Ideas of exploration

# %% [markdown]
# World map with exploding circles for conflicts over time and other animation for end of conflict (clashing swords vs. doves)
#
# Investigate unemployement rate vs. war likely
#
# Investigate conflict types
#
# Cost of war(time)
#
# Black market(region, time)
#
# One war leads to another rapidly?
