# %% [markdown]
# # Download dataset

# %%
# Download dataset from Kaggle using kagglehub library
import kagglehub

path = kagglehub.dataset_download("piterfm/milano-cortina-2026-olympic-winter-games")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 101k/101k [00:00<00:00, 524kB/s]
# Extracting files...
# Path to dataset files: /home/thomas/.cache/kagglehub/datasets/piterfm/milano-cortina-2026-olympic-winter-games/versions/11

# %% [markdown]
# # Initial dataset investigation

# %% [markdown]
# ## Athletes

# %%
# Load the dataset using pandas
import pandas as pd

df_athletes = pd.read_csv(path + "/athletes.csv")

# %%
df_athletes.shape
# Out:
# (2916, 6)

# %%
df_athletes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          2916 non-null   int64
#  1   name          2916 non-null   str
#  2   gender        2916 non-null   str
#  3   country_code  2916 non-null   str
#  4   flag_bearer   2916 non-null   int64
#  5   events        2916 non-null   str
# dtypes: int64(2), str(4)
# memory usage: 136.8 KB

# %%
df_athletes.head()
# Out:
#      code                    name gender country_code  flag_bearer  \
# 0  139893  AABREKK Ingrid Bergene      F          NOR            0
# 1   24464          AAGAARD Mikkel      M          DEN            0
# 2   45083             AALTO Antti      M          FIN            0
# 3   32319       ABATANGELO Aurora      F          ITA            0
# 4    4972              ABDI Fayik      M          KSA            0
#
#                                               events
# 0  [{'discipline': 'Cross-Country Skiing', 'event...
# 1     [{'discipline': 'Ice Hockey', 'event': 'Men'}]
# 2  [{'discipline': 'Ski Jumping', 'event': "Men's...
# 3   [{'discipline': 'Ice Hockey', 'event': 'Women'}]
# 4  [{'discipline': 'Alpine Skiing', 'event': "Men...

# %%
df_athletes.tail()
# Out:
#        code              name gender country_code  flag_bearer  \
# 2911  25116   ZUMWINKLE Grace      F          USA            0
# 2912  44328       ZUNTE Darta      F          EST            0
# 2913   7319   ZURBAY Anabelle      F          IRL            1
# 2914  19124  ZURBRIGGEN Anina      F          BUL            0
# 2915  23401      ZUREK Damian      M          POL            0
#
#                                                  events
# 2911   [{'discipline': 'Ice Hockey', 'event': 'Women'}]
# 2912     [{'discipline': 'Skeleton', 'event': 'Women'}]
# 2913  [{'discipline': 'Alpine Skiing', 'event': "Wom...
# 2914  [{'discipline': 'Alpine Skiing', 'event': "Wom...
# 2915  [{'discipline': 'Speed Skating', 'event': "Men...

# %%
df_athletes.describe()
# Out:
#                 code  flag_bearer
# count    2916.000000  2916.000000
# mean    36401.582990     0.122085
# std     16043.661964     0.470224
# min      4098.000000     0.000000
# 25%     24173.000000     0.000000
# 50%     39906.500000     0.000000
# 75%     45897.000000     0.000000
# max    170798.000000     3.000000

# %% [markdown]
# ## Coaches

# %%
# Load the dataset using pandas
import pandas as pd

df_coaches = pd.read_csv(path + "/coaches.csv")

# %%
df_coaches.shape
# Out:
# (50, 7)

# %%
df_coaches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          50 non-null     int64
#  1   name          50 non-null     str
#  2   gender        50 non-null     str
#  3   country_code  50 non-null     str
#  4   nationality   50 non-null     str
#  5   function      50 non-null     str
#  6   events        50 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 2.9 KB

# %%
df_coaches.head()
# Out:
#     code                name gender country_code nationality    function  \
# 0  50140       BOUCHARD Eric      M          ITA         CAN  Head Coach
# 1  50988  CERNOVSKY Vladimir      M          CZE         CZE       Coach
# 2  49020     CHARETTE Pierre      M          SUI         CAN       Coach
# 3  53809          COOPER Jon      M          CAN         CAN  Head Coach
# 4  49035       de CRUZ Peter      M          SUI         SUI       Coach
#
#                                               events
# 0   [{'discipline': 'Ice Hockey', 'event': 'Women'}]
# 1  [{'discipline': 'Curling', 'event': 'Mixed Dou...
# 2      [{'discipline': 'Curling', 'event': 'Women'}]
# 3     [{'discipline': 'Ice Hockey', 'event': 'Men'}]
# 4  [{'discipline': 'Curling', 'event': 'Mixed Dou...

# %%
df_coaches.tail()
# Out:
#      code             name gender country_code nationality    function  \
# 45  47166  VITOLINS Harijs      M          LAT         LAT  Head Coach
# 46  22959  WALSTAD Steffen      M          EST         NOR       Coach
# 47  53327     WEBSTER Paul      M          CAN         CAN       Coach
# 48  25178  WROBLEWSKI John      M          USA         USA  Head Coach
# 49  39951    ZANG Jialiang      M          CHN         CHN       Coach
#
#                                                events
# 45     [{'discipline': 'Ice Hockey', 'event': 'Men'}]
# 46  [{'discipline': 'Curling', 'event': 'Mixed Dou...
# 47        [{'discipline': 'Curling', 'event': 'Men'}]
# 48   [{'discipline': 'Ice Hockey', 'event': 'Women'}]
# 49      [{'discipline': 'Curling', 'event': 'Women'}]

# %%
df_coaches.describe()
# Out:
#                 code
# count      50.000000
# mean    41325.620000
# std     19130.461623
# min     18095.000000
# 25%     29014.000000
# 50%     41103.500000
# 75%     49326.250000
# max    149123.000000

# %% [markdown]
# ## Medallists

# %%
# Load the dataset using pandas
import pandas as pd

df_medallists = pd.read_csv(path + "/medallists.csv")

# %%
df_medallists.shape
# Out:
# (709, 11)

# %%
df_medallists.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             709 non-null    str
#  1   medal_code       709 non-null    int64
#  2   medal            709 non-null    str
#  3   code             709 non-null    int64
#  4   name             709 non-null    str
#  5   gender           709 non-null    str
#  6   country_code     709 non-null    str
#  7   country          709 non-null    str
#  8   discipline       709 non-null    str
#  9   discipline_code  709 non-null    str
#  10  event_name       709 non-null    str
# dtypes: int64(2), str(9)
# memory usage: 61.1 KB

# %%
df_medallists.head()
# Out:
#          date  medal_code   medal   code               name gender  \
# 0  2026-02-07           1    GOLD  48729  von ALLMEN Franjo      M
# 1  2026-02-07           2  SILVER  25998  FRANZONI Giovanni      M
# 2  2026-02-07           3  BRONZE  26002      PARIS Dominik      M
# 3  2026-02-07           1    GOLD  30739     KARLSSON Frida      F
# 4  2026-02-07           2  SILVER  30707     ANDERSSON Ebba      F
#
#   country_code      country            discipline discipline_code  \
# 0          SUI  Switzerland         Alpine Skiing             ALP
# 1          ITA        Italy         Alpine Skiing             ALP
# 2          ITA        Italy         Alpine Skiing             ALP
# 3          SWE       Sweden  Cross-Country Skiing             CCS
# 4          SWE       Sweden  Cross-Country Skiing             CCS
#
#                       event_name
# 0                 Men's Downhill
# 1                 Men's Downhill
# 2                 Men's Downhill
# ...

# %%
df_medallists.tail()
# Out:
#            date  medal_code   medal   code            name gender  \
# 704  2026-02-22           2  SILVER  53901     SUZUKI Nick      M
# 705  2026-02-22           2  SILVER  53905   THEODORE Shea      M
# 706  2026-02-22           2  SILVER  53907  THOMPSON Logan      M
# 707  2026-02-22           2  SILVER  53910     TOEWS Devon      M
# 708  2026-02-22           2  SILVER  53914      WILSON Tom      M
#
#     country_code country  discipline discipline_code event_name
# 704          CAN  Canada  Ice Hockey             IHO        Men
# 705          CAN  Canada  Ice Hockey             IHO        Men
# 706          CAN  Canada  Ice Hockey             IHO        Men
# 707          CAN  Canada  Ice Hockey             IHO        Men
# 708          CAN  Canada  Ice Hockey             IHO        Men

# %%
df_medallists.describe()
# Out:
#        medal_code           code
# count  709.000000     709.000000
# mean     1.994358   37871.267983
# std      0.814745   14925.077758
# min      1.000000    6464.000000
# 25%      1.000000   25029.000000
# 50%      2.000000   42254.000000
# 75%      3.000000   48300.000000
# max      3.000000  170798.000000

# %% [markdown]
# ## Medals

# %%
# Load the dataset using pandas
import pandas as pd

df_medals = pd.read_csv(path + "/medals.csv")

# %%
df_medals.shape
# Out:
# (29, 8)

# %%
df_medals.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       29 non-null     str
#  1   country_code  29 non-null     str
#  2   gold          29 non-null     int64
#  3   silver        29 non-null     int64
#  4   bronze        29 non-null     int64
#  5   total         29 non-null     int64
#  6   rank          29 non-null     int64
#  7   rank_total    29 non-null     int64
# dtypes: int64(6), str(2)
# memory usage: 1.9 KB

# %%
df_medals.head()
# Out:
#          country country_code  gold  silver  bronze  total  rank  rank_total
# 0         Norway          NOR    18      12      11     41     1           1
# 1  United States          USA    12      12       9     33     2           2
# 2    Netherlands          NED    10       7       3     20     3           9
# 3          Italy          ITA    10       6      14     30     4           3
# 4        Germany          GER     8      10       8     26     5           4

# %%
df_medals.tail()
# Out:
#      country country_code  gold  silver  bronze  total  rank  rank_total
# 24   Denmark          DEN     0       1       0      1    25          24
# 25   Estonia          EST     0       1       0      1    25          24
# 26   Georgia          GEO     0       1       0      1    25          24
# 27  Bulgaria          BUL     0       0       2      2    28          22
# 28   Belgium          BEL     0       0       1      1    29          24

# %%
df_medals.describe()
# Out:
#             gold     silver     bronze      total       rank  rank_total
# count  29.000000  29.000000  29.000000  29.000000  29.000000   29.000000
# mean    4.000000   4.034483   3.965517  12.000000  14.862069   14.241379
# std     4.511889   3.877432   4.083790  11.655777   8.356880    7.744377
# min     0.000000   0.000000   0.000000   1.000000   1.000000    1.000000
# 25%     0.000000   1.000000   1.000000   2.000000   8.000000    8.000000
# 50%     3.000000   2.000000   2.000000   6.000000  15.000000   14.000000
# 75%     6.000000   7.000000   6.000000  21.000000  22.000000   22.000000
# max    18.000000  12.000000  14.000000  41.000000  29.000000   24.000000

# %% [markdown]
# ## Schedules

# %%
# Load the dataset using pandas
import pandas as pd

df_schedules = pd.read_csv(path + "/schedules.csv")

# %%
df_schedules.shape
# Out:
# (1884, 16)

# %%
df_schedules.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   start_date       1884 non-null   str
#  1   end_date         1878 non-null   str
#  2   day              1884 non-null   str
#  3   status           1884 non-null   str
#  4   discipline       1884 non-null   str
#  5   discipline_code  1884 non-null   str
#  6   event            1884 non-null   str
#  7   event_medal      1884 non-null   int64
#  8   phase            1884 non-null   str
#  9   gender           1884 non-null   str
#  10  event_type       1884 non-null   str
#  11  venue            1884 non-null   str
#  12  venue_code       1884 non-null   str
#  13  location         1884 non-null   str
#  14  location_code    1884 non-null   str
#  15  id               1884 non-null   str
# dtypes: int64(1), str(15)
# memory usage: 235.6 KB

# %%
df_schedules.head()
# Out:
#                   start_date                   end_date         day    status  \
# 0  2026-02-04T11:30:00+01:00  2026-02-04T13:30:00+01:00  2026-02-04  FINISHED
# 1  2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04  FINISHED
# 2  2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04  FINISHED
# 3  2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04  FINISHED
# 4  2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04  FINISHED
#
#       discipline discipline_code           event  event_medal  \
# 0  Alpine Skiing             ALP  Men's Downhill            0
# 1        Curling             CUR   Mixed Doubles            0
# 2        Curling             CUR   Mixed Doubles            0
# 3        Curling             CUR   Mixed Doubles            0
# 4        Curling             CUR   Mixed Doubles            0
#
#                               phase gender event_type  \
# 0  Men's Downhill Official Training      M       INDV
# ...

# %%
df_schedules.tail()
# Out:
#                      start_date                   end_date         day  \
# 1879  2026-02-22T11:09:00+01:00  2026-02-22T11:34:00+01:00  2026-02-22
# 1880  2026-02-22T11:38:00+01:00  2026-02-22T12:03:00+01:00  2026-02-22
# 1881  2026-02-22T12:15:00+01:00  2026-02-22T13:00:00+01:00  2026-02-22
# 1882  2026-02-22T14:10:00+01:00  2026-02-22T16:40:00+01:00  2026-02-22
# 1883  2026-02-22T20:30:00+01:00  2026-02-22T23:00:00+01:00  2026-02-22
#
#          status        discipline discipline_code                     event  \
# 1879   FINISHED  Freestyle Skiing             FRS  Women's Freeski Halfpipe
# 1880   FINISHED  Freestyle Skiing             FRS  Women's Freeski Halfpipe
# 1881   FINISHED         Bobsleigh             BOB                     4-man
# 1882   FINISHED        Ice Hockey             IHO                       Men
# 1883  SCHEDULED        Ceremonies             CER          Closing Ceremony
#
#       event_medal                           phase gender event_type  \
# ...

# %%
df_schedules.describe()
# Out:
#        event_medal
# count  1884.000000
# mean      0.237261
# std       0.534991
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000

# %% [markdown]
# ## Teams

# %%
# Load the dataset using pandas
import pandas as pd

df_teams = pd.read_csv(path + "/teams.csv")

# %%
df_teams.shape
# Out:
# (550, 6)

# %%
df_teams.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          550 non-null    str
#  1   name          550 non-null    str
#  2   team_type     550 non-null    str
#  3   gender        550 non-null    str
#  4   country_code  550 non-null    str
#  5   events        550 non-null    str
# dtypes: str(6)
# memory usage: 25.9 KB

# %%
df_teams.head()
# Out:
#                 code                               name team_type gender  \
# 0  FSKXPAIRS---ARM01  AKOPOVA Karina / RAKHMANIN Nikita      CPLW      -
# 1  BOBMTEAM2---GER03                        AMMOUR Adam    CUSTOM      -
# 2  BOBMTEAM4---GER03                        AMMOUR Adam    CUSTOM      -
# 3  BOBWTEAM2---ITA01                    ANDREUTTI Giada    CUSTOM      -
# 4  SKNXRELAY2--LAT01   ANDZANE Marta / INDRIKSONS Emils      CPLW      -
#
#   country_code                                             events
# 0          ARM  [{'discipline': 'Figure Skating', 'event': 'Pa...
# 1          GER    [{'discipline': 'Bobsleigh', 'event': '2-man'}]
# 2          GER    [{'discipline': 'Bobsleigh', 'event': '4-man'}]
# 3          ITA  [{'discipline': 'Bobsleigh', 'event': '2-woman'}]
# 4          LAT  [{'discipline': 'Skeleton', 'event': 'Mixed Te...

# %%
df_teams.tail()
# Out:
#                   code                            name team_type gender  \
# 545  BOBMTEAM2---NED01                  WESSELINK Dave    CUSTOM      -
# 546  BOBWTEAM2---CHN02                       YING Qing    CUSTOM      -
# 547  FSKXICEDANCEJPN01   YOSHIDA Utana / MORITA Masaya      CPLW      X
# 548  SKNXRELAY2--CHN02          ZHAO Dan / CHEN Wenhao      CPLW      -
# 549  FSKXICEDANCEUSA02  ZINGAS Emilea / KOLESNIK Vadym      CPLW      -
#
#     country_code                                             events
# 545          NED    [{'discipline': 'Bobsleigh', 'event': '2-man'}]
# 546          CHN  [{'discipline': 'Bobsleigh', 'event': '2-woman'}]
# 547          JPN  [{'discipline': 'Figure Skating', 'event': 'Te...
# 548          CHN  [{'discipline': 'Skeleton', 'event': 'Mixed Te...
# 549          USA  [{'discipline': 'Figure Skating', 'event': 'Ic...

# %%
df_teams.describe()
# Out:
#                      code                      name team_type gender  \
# count                 550                       550       550    550
# unique                550                       205         5      4
# top     FSKXPAIRS---ARM01  United States of America       ORG      -
# freq                    1                        24       329    242
#
#        country_code                                             events
# count           550                                                550
# unique           43                                                 39
# top             USA  [{'discipline': 'Alpine Skiing', 'event': "Wom...
# freq             46                                                 28

# %% [markdown]
# Name is either individuals or country.

# %% [markdown]
# ## Venues

# %%
# Load the dataset using pandas
import pandas as pd

df_venues = pd.read_csv(path + "/venues.csv")

# %%
df_venues.shape
# Out:
# (15, 6)

# %%
df_venues.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   venue             15 non-null     str
#  1   venue_code        15 non-null     str
#  2   disciplines       13 non-null     str
#  3   disciplines_code  13 non-null     str
#  4   url_sport         7 non-null      str
#  5   url_venue         15 non-null     str
# dtypes: str(6)
# memory usage: 852.0 bytes

# %%
df_venues.head()
# Out:
#                              venue venue_code  \
# 0        Anterselva Biathlon Arena        ABA
# 1  Cortina Curling Olympic Stadium        CCU
# 2           Cortina Sliding Centre        CSC
# 3    Livigno Aerials & Moguls Park        LAM
# 4                Livigno Snow Park        LSP
#
#                                          disciplines     disciplines_code  \
# 0                                discipline-biathlon                  BTH
# 1                                 discipline-curling                  CUR
# 2  ["discipline-bobsleigh","discipline-luge","dis...  ["BOB","LUG","SKN"]
# 3                        discipline-freestyle-skiing                  FRS
# 4  ["discipline-freestyle-skiing","discipline-sno...        ["FRS","SBD"]
#
#                                            url_sport  \
# 0       https://www.olympics.com/en/sports/biathlon/
# 1        https://www.olympics.com/en/sports/curling/
# 2                                                NaN
# ...

# %%
df_venues.tail()
# Out:
#                                   venue venue_code  \
# 10         Predazzo Ski Jumping Stadium        PSJ
# 11                   Stelvio Ski Centre        SSC
# 12  Tesero Cross-Country Skiing Stadium        TCC
# 13          Tofane Alpine Skiing Centre        CAL
# 14                 Verona Olympic Arena        VOA
#
#                                           disciplines disciplines_code  \
# 10  ["discipline-nordic-combined","discipline-ski-...    ["NCB","SJP"]
# 11  ["discipline-alpine-skiing","discipline-ski-mo...    ["ALP","SMT"]
# 12  ["discipline-cross-country-skiing","discipline...    ["CCS","NCB"]
# 13                           discipline-alpine-skiing              ALP
# 14                                                NaN              NaN
#
#                                             url_sport  \
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# ...

# %%
df_venues.describe()
# Out:
#                             venue venue_code            disciplines  \
# count                          15         15                     13
# unique                         15         15                     12
# top     Anterselva Biathlon Arena        ABA  discipline-ice-hockey
# freq                            1          1                      2
#
#        disciplines_code                                       url_sport  \
# count                13                                               7
# unique               12                                               6
# top                 IHO  https://www.olympics.com/en/sports/ice-hockey/
# freq                  2                                               2
#
#                                                 url_venue
# count                                                  15
# unique                                                 15
# top     https://www.olympics.com/en/milano-cortina-202...
# ...

# %% [markdown]
# Name is either individuals or country.

# %% [markdown]
# # Quality check

# %% [markdown]
# ## Athletes

# %%
duplicated_rows = df_athletes[df_athletes.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [code, name, gender, country_code, flag_bearer, events]
# Index: []

# %%
df_athletes.nunique()
# Out:
# code            2916
# name            2916
# gender             2
# country_code      93
# flag_bearer        4
# events           344
# dtype: int64

# %% [markdown]
# Complete dataset for athletes. Extra flag bearer info.

# %% [markdown]
# ## Coaches

# %%
duplicated_rows = df_coaches[df_coaches.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [code, name, gender, country_code, flag_bearer, events]
# Index: []

# %%
df_coaches.nunique()
# Out:
# code            50
# name            50
# gender           2
# country_code    18
# nationality     15
# function         2
# events           8
# dtype: int64

# %% [markdown]
# Incomplete dataset for coaches (only 50).

# %% [markdown]
# ## Medallists

# %%
duplicated_rows = df_medallists[df_medallists.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [date, medal_code, medal, code, name, gender, country_code, country, discipline, discipline_code, event_name]
# Index: []

# %%
df_medallists.nunique()
# Out:
# date                16
# medal_code           3
# medal                3
# code               534
# name               534
# gender               2
# country_code        30
# country             30
# discipline          16
# discipline_code     16
# event_name         104
# dtype: int64

# %% [markdown]
# Looks like 31 medals are missing. Can fill dataset by hand.

# %% [markdown]
# ## Medals

# %%
duplicated_rows = df_medals[df_medals.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [country, country_code, gold, silver, bronze, total, rank, rank_total]
# Index: []

# %%
df_medals.nunique()
# Out:
# country         29
# country_code    29
# gold            10
# silver          11
# bronze          12
# total           17
# rank            26
# rank_total      17
# dtype: int64

# %%
df_medals["total"].sum()
# Out:
# np.int64(348)

# %% [markdown]
# Only one medal per sport not per individual (740 vs. 348). Complete sub-dataset.

# %% [markdown]
# ## Schedules

# %%
duplicated_rows = df_schedules[df_schedules.duplicated()]
duplicated_rows
# Out:
#                      start_date                   end_date         day  \
# 7     2026-02-04T11:30:00+01:00  2026-02-04T13:30:00+01:00  2026-02-04
# 8     2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04
# 9     2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04
# 10    2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04
# 11    2026-02-04T19:05:00+01:00  2026-02-04T21:00:00+01:00  2026-02-04
# ...                         ...                        ...         ...
# 1879  2026-02-22T11:09:00+01:00  2026-02-22T11:34:00+01:00  2026-02-22
# 1880  2026-02-22T11:38:00+01:00  2026-02-22T12:03:00+01:00  2026-02-22
# 1881  2026-02-22T12:15:00+01:00  2026-02-22T13:00:00+01:00  2026-02-22
# 1882  2026-02-22T14:10:00+01:00  2026-02-22T16:40:00+01:00  2026-02-22
# 1883  2026-02-22T20:30:00+01:00  2026-02-22T23:00:00+01:00  2026-02-22
#
#          status        discipline discipline_code                     event  \
# ...

# %%
df_schedules_unique = df_schedules.drop_duplicates()
df_schedules_unique.shape
# Out:
# (628, 16)

# %%
df_schedules_unique.nunique()
# Out:
# start_date         485
# end_date           503
# day                 19
# status               3
# discipline          17
# discipline_code     17
# event              112
# event_medal          3
# phase              245
# gender               4
# event_type           5
# venue               15
# venue_code          15
# location            25
# location_code       25
# id                 628
# dtype: int64

# %%
df_schedules_unique.groupby("status").size()
# Out:
# status
# CANCELLED      3
# FINISHED     624
# SCHEDULED      1
# dtype: int64

# %%
phase_cancelled = df_schedules_unique[df_schedules_unique["status"] == "CANCELLED"]["phase"]
phase_cancelled
# Out:
# 18      Women's Downhill Official Training
# 1246                      Men's Super Team
# 1353           Women's Team Pursuit Finals
# Name: phase, dtype: str

# %%
df_schedules_unique[df_schedules_unique["phase"].isin(phase_cancelled)]
# Out:
#                      start_date                   end_date         day  \
# 18    2026-02-05T11:30:00+01:00                        NaN  2026-02-05
# 76    2026-02-06T11:30:00+01:00  2026-02-06T13:30:00+01:00  2026-02-06
# 132   2026-02-07T11:30:00+01:00  2026-02-07T13:30:00+01:00  2026-02-07
# 1237  2026-02-16T18:00:00+01:00  2026-02-16T18:35:00+01:00  2026-02-16
# 1239  2026-02-16T19:00:00+01:00  2026-02-16T19:35:00+01:00  2026-02-16
# 1244  2026-02-16T19:50:00+01:00  2026-02-16T20:16:00+01:00  2026-02-16
# 1246  2026-02-16T20:31:00+01:00                        NaN  2026-02-16
# 1353  2026-02-17T15:43:00+01:00  2026-02-17T15:49:00+01:00  2026-02-17
# 1354  2026-02-17T15:49:00+01:00  2026-02-17T15:55:00+01:00  2026-02-17
# 1358  2026-02-17T16:41:00+01:00  2026-02-17T16:47:00+01:00  2026-02-17
# 1359  2026-02-17T16:47:00+01:00  2026-02-17T16:53:00+01:00  2026-02-17
#
#          status     discipline discipline_code                 event  \
# ...

# %% [markdown]
# Watch out for duplicates! Scheduled is the ceremony (see tail) which is also the reason for 17 "disciplines" even though only 16 took place. Drop cancelled events + ceremony (depending on analysis). Cancelled events took place afterwards.

# %% [markdown]
# ## Teams

# %%
duplicated_rows = df_teams[df_teams.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [code, name, team_type, gender, country_code, events]
# Index: []

# %%
df_teams.nunique()
# Out:
# code            550
# name            205
# team_type         5
# gender            4
# country_code     43
# events           39
# dtype: int64

# %%
df_teams.groupby("team_type").size()
# Out:
# team_type
# CPLP       28
# CPLW       59
# CUSTOM     78
# ORG       329
# ORGN       56
# dtype: int64

# %%
countries_athletes = set(df_athletes["country_code"])
countries_teams = set(df_teams["country_code"])

missing_countries = countries_athletes - countries_teams


missing_countries
# Out:
# {'AIN',
#  'ALB',
#  'AND',
#  'AZE',
#  'BEN',
#  'BIH',
#  'BOL',
#  'CHI',
#  'COL',
#  'CYP',
#  'ECU',
#  'ERI',
#  'GBS',
#  'HAI',
#  'HKG',
#  'IND',
#  'IRI',
#  'IRL',
#  'ISL',
#  'KEN',
#  'KGZ',
#  'KOS',
#  'KSA',
#  'LBN',
#  'LUX',
#  'MAD',
#  'MAR',
#  'MAS',
#  'MDA',
#  'MEX',
#  'MGL',
#  'MKD',
#  'MLT',
#  'MNE',
#  'MON',
#  'NGR',
#  'NZL',
#  'PAK',
#  'PHI',
#  'POR',
#  'PUR',
#  'RSA',
#  'SGP',
#  'SMR',
#  'SRB',
#  'THA',
#  'UAE',
#  'URU',
#  'UZB',
#  'VEN'}

# %%
len(set(df_teams["events"].apply(lambda x: x[0]["discipline"])))
# Out:
# 16

# %% [markdown]
# CPLP: CouPle Link Pair
#
# CPLW: CouPle Link
#
# CUSTOM: Individuals
#
# ORG: Official Team
#
# ORGN: Official Team (when multiple teams)

# %% [markdown]
# Requires further processing to complete gender data ("-" to "X"/"M"/"F") through "event" column.

# %% [markdown]
# Looks like team sub-dataset is incomplete. Missing countries representation. Use sub-dataset with care.

# %% [markdown]
# ## Venues

# %%
duplicated_rows = df_venues[df_venues.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [venue, venue_code, disciplines, disciplines_code, url_sport, url_venue]
# Index: []

# %%
df_venues.nunique()
# Out:
# venue               15
# venue_code          15
# disciplines         12
# disciplines_code    12
# url_sport            6
# url_venue           15
# dtype: int64

# %% [markdown]
# Need to manually complete sub-dataset. Should be quick as it is small.

# %% [markdown]
# # Ideas of exploration

# %% [markdown]
# Local map with events clickable to enter new page dedicated to sports which took place there
#
# Look into past winter olympics and see dynasties/new comers in Milan 2026
#
# Look into visitors/economical/environmentals impacts
#
# Do animation where we see dots arriving to the games (1 dot per athlete): start animation
#
# Classic medal race
#
# Flag bearers (legendary figures)
#
# Are coaches old legends? And do they work for their country OR the best country in the domain OR rich country.
#
# Men vs Women in discipline per country
#
# Team sports per country
#
# Most exploited areas (see schedule)
#
# Which sports have most medals (where to specialize if medal race is the goal)
#
# Use sports/venue URL to redirect to Olympics official website

# %% [markdown]
# Don't forget to cite dataset!
